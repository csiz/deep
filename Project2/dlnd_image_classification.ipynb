# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 33
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 33:
# Image - Min Value: 1 Max Value: 239
# Image - Shape: (32, 32, 3)
# Label - Label Id: 3 Name: cat

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    
    return np.array(x) / 256


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
import tensorflow as tf

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    with tf.Session():
        return tf.one_hot(x, depth=10).eval()


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# My Stuff
# --------
#
# 1. To build shapes I copied the unroll function which recursively flattens lists.
#
# 2. ReLU that doesn't die.

# %%
import collections

def unroll(*args):
    """Unroll a possibly nested list for easy dimensions.
        https://stackoverflow.com/questions/2158395/flatten-an-irregular-list-of-lists-in-python
    """
    def impl(l):
        for el in l:
            if isinstance(el, collections.Iterable) and not isinstance(el, (str, bytes)):
                yield from impl(el)
            else:
                yield el
                
    return list(impl(args))

unroll(1, [2, 3], [[4, 5]])
# Out:
# [1, 2, 3, 4, 5]

# %%
def prelu(x):
    params = tf.Variable(tf.ones(x.shape.as_list()[1:]))
    return tf.minimum(x, 0.0)*params + tf.maximum(x, 0.0)

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    return tf.placeholder(tf.float32, shape=(None,)+image_shape, name="x")


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    return tf.placeholder(tf.float32, shape=(None, n_classes), name="y")


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    return tf.placeholder(tf.float32, shape=None, name="keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    in_shape = x_tensor.shape.as_list()
    print("in_shape", in_shape)
    
    channels = in_shape[3]
    
    in_w, in_h = in_shape[1:3]
    s_w, s_h = conv_strides
    out_w, out_h = in_w/s_w, in_h/s_h
    rel_size = (channels*in_w*in_h) / (conv_num_outputs*out_w*out_h)
    
    weight = tf.Variable(tf.truncated_normal(unroll(conv_ksize, channels, conv_num_outputs)) / rel_size)
    bias = tf.Variable(tf.zeros([conv_num_outputs]))
    
    conv_layer = tf.nn.conv2d(x_tensor, weight, strides=unroll(1, conv_strides, 1), padding="SAME")
    conv_layer = tf.nn.bias_add(conv_layer, bias)
    
    print("conv_shape", conv_layer.shape.as_list())
    
    conv_layer = prelu(conv_layer)

    conv_layer = tf.nn.max_pool(conv_layer, unroll(1, pool_ksize, 1), unroll(1, pool_strides, 1), padding="SAME")
    
    print("out_shape", conv_layer.shape.as_list())
    return conv_layer

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# in_shape [None, 32, 32, 5]
# conv_shape [None, 8, 8, 10]
# out_shape [None, 4, 4, 10]
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
import numpy as np

def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    inputsize = np.prod(x_tensor.shape[1:].as_list())
    return tf.reshape(x_tensor, [-1, inputsize])


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    in_shape = x_tensor.shape.as_list()
    print("full_in", in_shape)
    rel_size = in_shape[1] / num_outputs
    
    
    weights = tf.Variable(tf.truncated_normal(unroll(x_tensor.shape[1:].as_list(), num_outputs)) / rel_size)
    bias = tf.Variable(tf.zeros([num_outputs]))
    
    conn_layer = tf.add(tf.matmul(x_tensor, weights), bias)
    conn_layer = prelu(conn_layer)
    
    print("full_out", conn_layer.shape.as_list())
    return conn_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# full_in [None, 128]
# full_out [None, 40]
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    weights = tf.Variable(tf.truncated_normal(unroll(x_tensor.shape[1:].as_list(), num_outputs)))
    bias = tf.Variable(tf.zeros([num_outputs]))
    
    conn_layer = tf.add(tf.matmul(x_tensor, weights), bias)
    
    
    return conn_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    x = conv2d_maxpool(x, 8, [8, 8], [2, 2], [2, 2], [2, 2])
    
    x = conv2d_maxpool(x, 16, [4, 4], [1, 1], [2, 2], [2, 2])

    # x = conv2d_maxpool(x, 32, [4, 4], [1, 1], [2, 2], [2, 2])
    

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    x = flatten(x)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    
    x = fully_conn(x, 64)
    
    x = fully_conn(x, 32)
    
    x = tf.nn.dropout(x, keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    x = output(x, 10)
    
    # TODO: return output
    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE

* added a print for debugging
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

print("Build network; now testing...")

tests.test_conv_net(conv_net)
# Out:
# in_shape [None, 32, 32, 3]
# conv_shape [None, 16, 16, 8]
# out_shape [None, 8, 8, 8]
# in_shape [None, 8, 8, 8]
# conv_shape [None, 8, 8, 16]
# out_shape [None, 4, 4, 16]
# full_in [None, 256]
# full_out [None, 64]
# full_in [None, 64]
# full_out [None, 32]
# Build network; now testing...
# in_shape [None, 32, 32, 3]
# conv_shape [None, 16, 16, 8]
# out_shape [None, 8, 8, 8]
# in_shape [None, 8, 8, 8]
# conv_shape [None, 8, 8, 16]
# out_shape [None, 4, 4, 16]
# full_in [None, 256]
# full_out [None, 64]
# full_in [None, 64]
# full_out [None, 32]
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    
    session.run(optimizer, feed_dict={x: feature_batch, y: label_batch, keep_prob: keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    train_cost, train_accuracy = session.run([cost, accuracy], feed_dict={x: feature_batch, y: label_batch, keep_prob: 1.0})
    valid_cost, valid_accuracy = session.run([cost, accuracy], feed_dict={x: valid_features, y: valid_labels, keep_prob: 1.0})
    print("")
    print("  Train Cost: {:>10.5f}; Train Accuracy: {:>6.1%}".format(train_cost, train_accuracy))
    print("  Valid Cost: {:>10.5f}; Valid Accuracy: {:>6.1%}".format(valid_cost, valid_accuracy))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 64
batch_size = 64
keep_probability = 0.9

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:
#   Train Cost:  712.06915; Train Accuracy:  15.0%
#   Valid Cost:  650.89178; Valid Accuracy:  21.2%
# Epoch  2, CIFAR-10 Batch 1:
#   Train Cost:  506.73077; Train Accuracy:  12.5%
#   Valid Cost:  438.93710; Valid Accuracy:  24.6%
# Epoch  3, CIFAR-10 Batch 1:
#   Train Cost:  405.80475; Train Accuracy:  20.0%
#   Valid Cost:  338.66769; Valid Accuracy:  25.5%
# Epoch  4, CIFAR-10 Batch 1:
#   Train Cost:  282.61517; Train Accuracy:  27.5%
#   Valid Cost:  263.88681; Valid Accuracy:  27.0%
# Epoch  5, CIFAR-10 Batch 1:
#   Train Cost:  226.69528; Train Accuracy:  30.0%
#   Valid Cost:  210.44087; Valid Accuracy:  27.9%
# Epoch  6, CIFAR-10 Batch 1:
#   Train Cost:  180.73715; Train Accuracy:  40.0%
#   Valid Cost:  175.10095; Valid Accuracy:  29.1%
# Epoch  7, CIFAR-10 Batch 1:
#   Train Cost:  139.25095; Train Accuracy:  37.5%
#   Valid Cost:  144.55573; Valid Accuracy:  30.2%
# Epoch  8, CIFAR-10 Batch 1:
#   Train Cost:  122.22896; Train Accuracy:  42.5%
#   Valid Cost:  122.97360; Valid Accuracy:  31.2%
# Epoch  9, CIFAR-10 Batch 1:
#   Train Cost:   96.50050; Train Accuracy:  45.0%
#   Valid Cost:  105.30800; Valid Accuracy:  31.4%
# Epoch 10, CIFAR-10 Batch 1:
#   Train Cost:   88.62148; Train Accuracy:  37.5%
#   Valid Cost:   92.35159; Valid Accuracy:  32.0%
# Epoch 11, CIFAR-10 Batch 1:
#   Train Cost:   70.62630; Train Accuracy:  40.0%
#   Valid Cost:   80.62004; Valid Accuracy:  32.8%
# Epoch 12, CIFAR-10 Batch 1:
#   Train Cost:   68.33720; Train Accuracy:  42.5%
#   Valid Cost:   73.40186; Valid Accuracy:  32.2%
# Epoch 13, CIFAR-10 Batch 1:
#   Train Cost:   57.06522; Train Accuracy:  40.0%
#   Valid Cost:   64.87019; Valid Accuracy:  33.3%
# Epoch 14, CIFAR-10 Batch 1:
#   Train Cost:   51.33341; Train Accuracy:  35.0%
#   Valid Cost:   59.13214; Valid Accuracy:  32.7%
# Epoch 15, CIFAR-10 Batch 1:
#   Train Cost:   44.94797; Train Accuracy:  40.0%
#   Valid Cost:   52.50793; Valid Accuracy:  33.3%
# Epoch 16, CIFAR-10 Batch 1:
#   Train Cost:   39.68211; Train Accuracy:  45.0%
#   Valid Cost:   48.11137; Valid Accuracy:  33.4%
# Epoch 17, CIFAR-10 Batch 1:
#   Train Cost:   31.20516; Train Accuracy:  45.0%
#   Valid Cost:   44.11306; Valid Accuracy:  33.3%
# Epoch 18, CIFAR-10 Batch 1:
#   Train Cost:   28.53128; Train Accuracy:  52.5%
#   Valid Cost:   39.19334; Valid Accuracy:  33.6%
# Epoch 19, CIFAR-10 Batch 1:
#   Train Cost:   25.95214; Train Accuracy:  50.0%
#   Valid Cost:   35.95495; Valid Accuracy:  33.2%
# Epoch 20, CIFAR-10 Batch 1:
#   Train Cost:   28.29669; Train Accuracy:  45.0%
#   Valid Cost:   33.89045; Valid Accuracy:  33.6%
# Epoch 21, CIFAR-10 Batch 1:
#   Train Cost:   21.22223; Train Accuracy:  45.0%
#   Valid Cost:   30.62790; Valid Accuracy:  33.9%
# Epoch 22, CIFAR-10 Batch 1:
#   Train Cost:   19.83090; Train Accuracy:  45.0%
#   Valid Cost:   28.51309; Valid Accuracy:  32.6%
# Epoch 23, CIFAR-10 Batch 1:
#   Train Cost:   17.84801; Train Accuracy:  42.5%
#   Valid Cost:   25.81582; Valid Accuracy:  33.4%
# Epoch 24, CIFAR-10 Batch 1:
#   Train Cost:   16.34635; Train Accuracy:  45.0%
#   Valid Cost:   24.10838; Valid Accuracy:  33.0%
# Epoch 25, CIFAR-10 Batch 1:
#   Train Cost:   14.16813; Train Accuracy:  50.0%
#   Valid Cost:   21.97278; Valid Accuracy:  33.6%
# Epoch 26, CIFAR-10 Batch 1:
#   Train Cost:   12.73866; Train Accuracy:  45.0%
#   Valid Cost:   20.36674; Valid Accuracy:  33.1%
# Epoch 27, CIFAR-10 Batch 1:
#   Train Cost:   11.58708; Train Accuracy:  45.0%
#   Valid Cost:   18.69286; Valid Accuracy:  33.3%
# Epoch 28, CIFAR-10 Batch 1:
#   Train Cost:   11.20342; Train Accuracy:  47.5%
#   Valid Cost:   18.49286; Valid Accuracy:  33.1%
# Epoch 29, CIFAR-10 Batch 1:
#   Train Cost:    9.52694; Train Accuracy:  50.0%
#   Valid Cost:   16.07899; Valid Accuracy:  33.4%
# Epoch 30, CIFAR-10 Batch 1:
#   Train Cost:    8.71834; Train Accuracy:  50.0%
#   Valid Cost:   15.18059; Valid Accuracy:  33.4%
# Epoch 31, CIFAR-10 Batch 1:
#   Train Cost:    7.58831; Train Accuracy:  47.5%
#   Valid Cost:   13.96703; Valid Accuracy:  33.5%
# Epoch 32, CIFAR-10 Batch 1:
#   Train Cost:    6.89753; Train Accuracy:  47.5%
#   Valid Cost:   13.30246; Valid Accuracy:  32.3%
# Epoch 33, CIFAR-10 Batch 1:
#   Train Cost:    6.05747; Train Accuracy:  50.0%
#   Valid Cost:   11.44036; Valid Accuracy:  31.9%
# Epoch 34, CIFAR-10 Batch 1:
#   Train Cost:    5.15748; Train Accuracy:  50.0%
#   Valid Cost:   10.93632; Valid Accuracy:  32.9%
# Epoch 35, CIFAR-10 Batch 1:
#   Train Cost:    4.70069; Train Accuracy:  47.5%
#   Valid Cost:   10.26864; Valid Accuracy:  32.4%
# Epoch 36, CIFAR-10 Batch 1:
#   Train Cost:    4.16331; Train Accuracy:  52.5%
#   Valid Cost:    9.10986; Valid Accuracy:  33.5%
# Epoch 37, CIFAR-10 Batch 1:
#   Train Cost:    4.20303; Train Accuracy:  45.0%
#   Valid Cost:    8.22716; Valid Accuracy:  32.5%
# Epoch 38, CIFAR-10 Batch 1:
#   Train Cost:    3.83102; Train Accuracy:  52.5%
#   Valid Cost:    7.79888; Valid Accuracy:  32.8%
# Epoch 39, CIFAR-10 Batch 1:
#   Train Cost:    3.12173; Train Accuracy:  55.0%
#   Valid Cost:    7.09349; Valid Accuracy:  32.9%
# Epoch 40, CIFAR-10 Batch 1:
#   Train Cost:    2.87720; Train Accuracy:  57.5%
#   Valid Cost:    6.66117; Valid Accuracy:  32.7%
# Epoch 41, CIFAR-10 Batch 1:
#   Train Cost:    2.60238; Train Accuracy:  52.5%
#   Valid Cost:    5.36652; Valid Accuracy:  32.4%
# Epoch 42, CIFAR-10 Batch 1:
#   Train Cost:    2.46261; Train Accuracy:  50.0%
#   Valid Cost:    4.98018; Valid Accuracy:  33.2%
# Epoch 43, CIFAR-10 Batch 1:
#   Train Cost:    2.14170; Train Accuracy:  52.5%
#   Valid Cost:    4.81561; Valid Accuracy:  32.8%
# Epoch 44, CIFAR-10 Batch 1:
#   Train Cost:    2.05689; Train Accuracy:  50.0%
#   Valid Cost:    4.15298; Valid Accuracy:  33.4%
# Epoch 45, CIFAR-10 Batch 1:
#   Train Cost:    1.79051; Train Accuracy:  50.0%
#   Valid Cost:    3.98721; Valid Accuracy:  33.2%
# Epoch 46, CIFAR-10 Batch 1:
#   Train Cost:    1.71004; Train Accuracy:  52.5%
#   Valid Cost:    3.53172; Valid Accuracy:  32.7%
# Epoch 47, CIFAR-10 Batch 1:
#   Train Cost:    1.62933; Train Accuracy:  50.0%
#   Valid Cost:    3.34338; Valid Accuracy:  33.0%
# Epoch 48, CIFAR-10 Batch 1:
#   Train Cost:    1.53524; Train Accuracy:  50.0%
#   Valid Cost:    3.19321; Valid Accuracy:  32.3%
# Epoch 49, CIFAR-10 Batch 1:
#   Train Cost:    1.43799; Train Accuracy:  55.0%
#   Valid Cost:    2.74195; Valid Accuracy:  33.8%
# Epoch 50, CIFAR-10 Batch 1:
#   Train Cost:    1.49562; Train Accuracy:  55.0%
#   Valid Cost:    2.69470; Valid Accuracy:  32.7%
# Epoch 51, CIFAR-10 Batch 1:
#   Train Cost:    1.40631; Train Accuracy:  55.0%
#   Valid Cost:    2.56013; Valid Accuracy:  33.9%
# Epoch 52, CIFAR-10 Batch 1:
#   Train Cost:    1.40498; Train Accuracy:  57.5%
#   Valid Cost:    2.43972; Valid Accuracy:  33.3%
# Epoch 53, CIFAR-10 Batch 1:
#   Train Cost:    1.38224; Train Accuracy:  55.0%
#   Valid Cost:    2.38361; Valid Accuracy:  34.5%
# Epoch 54, CIFAR-10 Batch 1:
#   Train Cost:    1.39549; Train Accuracy:  52.5%
#   Valid Cost:    2.34193; Valid Accuracy:  34.1%
# Epoch 55, CIFAR-10 Batch 1:
#   Train Cost:    1.42464; Train Accuracy:  47.5%
#   Valid Cost:    2.31659; Valid Accuracy:  34.3%
# Epoch 56, CIFAR-10 Batch 1:
#   Train Cost:    1.39348; Train Accuracy:  50.0%
#   Valid Cost:    2.25092; Valid Accuracy:  34.5%
# Epoch 57, CIFAR-10 Batch 1:
#   Train Cost:    1.41671; Train Accuracy:  52.5%
#   Valid Cost:    2.32631; Valid Accuracy:  34.6%
# Epoch 58, CIFAR-10 Batch 1:
#   Train Cost:    1.38827; Train Accuracy:  50.0%
#   Valid Cost:    2.34923; Valid Accuracy:  34.7%
# Epoch 59, CIFAR-10 Batch 1:
#   Train Cost:    1.36257; Train Accuracy:  47.5%
#   Valid Cost:    2.27975; Valid Accuracy:  35.1%
# Epoch 60, CIFAR-10 Batch 1:
#   Train Cost:    1.36391; Train Accuracy:  52.5%
#   Valid Cost:    2.28259; Valid Accuracy:  35.0%
# Epoch 61, CIFAR-10 Batch 1:
#   Train Cost:    1.34830; Train Accuracy:  55.0%
#   Valid Cost:    2.26461; Valid Accuracy:  35.7%
# Epoch 62, CIFAR-10 Batch 1:
#   Train Cost:    1.34518; Train Accuracy:  55.0%
#   Valid Cost:    2.32691; Valid Accuracy:  35.2%
# Epoch 63, CIFAR-10 Batch 1:
#   Train Cost:    1.32641; Train Accuracy:  62.5%
#   Valid Cost:    2.33023; Valid Accuracy:  35.5%
# Epoch 64, CIFAR-10 Batch 1:
#   Train Cost:    1.36149; Train Accuracy:  57.5%
#   Valid Cost:    2.22215; Valid Accuracy:  35.8%

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:
#   Train Cost:  678.14386; Train Accuracy:  20.0%
#   Valid Cost:  679.01233; Valid Accuracy:  23.7%
# Epoch  1, CIFAR-10 Batch 2:
#   Train Cost:  457.99203; Train Accuracy:  20.0%
#   Valid Cost:  468.84976; Valid Accuracy:  26.0%
# Epoch  1, CIFAR-10 Batch 3:
#   Train Cost:  386.82608; Train Accuracy:  20.0%
#   Valid Cost:  354.01880; Valid Accuracy:  28.2%
# Epoch  1, CIFAR-10 Batch 4:
#   Train Cost:  278.03946; Train Accuracy:  25.0%
#   Valid Cost:  264.08945; Valid Accuracy:  30.7%
# Epoch  1, CIFAR-10 Batch 5:
#   Train Cost:  168.45808; Train Accuracy:  35.0%
#   Valid Cost:  224.06795; Valid Accuracy:  29.9%
# Epoch  2, CIFAR-10 Batch 1:
#   Train Cost:  211.83743; Train Accuracy:  27.5%
#   Valid Cost:  180.12280; Valid Accuracy:  31.4%
# Epoch  2, CIFAR-10 Batch 2:
#   Train Cost:  163.04121; Train Accuracy:  25.0%
#   Valid Cost:  148.00047; Valid Accuracy:  31.1%
# Epoch  2, CIFAR-10 Batch 3:
#   Train Cost:  160.94710; Train Accuracy:  22.5%
#   Valid Cost:  129.45883; Valid Accuracy:  32.7%
# Epoch  2, CIFAR-10 Batch 4:
#   Train Cost:  101.23958; Train Accuracy:  30.0%
#   Valid Cost:  106.26595; Valid Accuracy:  32.7%
# Epoch  2, CIFAR-10 Batch 5:
#   Train Cost:   62.36535; Train Accuracy:  42.5%
#   Valid Cost:   93.70763; Valid Accuracy:  32.9%
# Epoch  3, CIFAR-10 Batch 1:
#   Train Cost:   99.63559; Train Accuracy:  30.0%
#   Valid Cost:   80.62003; Valid Accuracy:  33.5%
# Epoch  3, CIFAR-10 Batch 2:
#   Train Cost:   73.92593; Train Accuracy:  27.5%
#   Valid Cost:   71.35830; Valid Accuracy:  34.0%
# Epoch  3, CIFAR-10 Batch 3:
#   Train Cost:   65.17136; Train Accuracy:  30.0%
#   Valid Cost:   63.27362; Valid Accuracy:  35.0%
# Epoch  3, CIFAR-10 Batch 4:
#   Train Cost:   49.88728; Train Accuracy:  25.0%
#   Valid Cost:   54.60979; Valid Accuracy:  35.1%
# Epoch  3, CIFAR-10 Batch 5:
#   Train Cost:   30.92864; Train Accuracy:  42.5%
#   Valid Cost:   49.61073; Valid Accuracy:  34.5%
# Epoch  4, CIFAR-10 Batch 1:
#   Train Cost:   54.02140; Train Accuracy:  20.0%
#   Valid Cost:   44.44491; Valid Accuracy:  34.9%
# Epoch  4, CIFAR-10 Batch 2:
#   Train Cost:   35.83317; Train Accuracy:  32.5%
#   Valid Cost:   40.53074; Valid Accuracy:  34.3%
# Epoch  4, CIFAR-10 Batch 3:
#   Train Cost:   35.55533; Train Accuracy:  40.0%
#   Valid Cost:   38.31990; Valid Accuracy:  35.4%
# Epoch  4, CIFAR-10 Batch 4:
#   Train Cost:   28.31513; Train Accuracy:  37.5%
#   Valid Cost:   32.04925; Valid Accuracy:  36.7%
# Epoch  4, CIFAR-10 Batch 5:
#   Train Cost:   18.72197; Train Accuracy:  37.5%
#   Valid Cost:   28.65690; Valid Accuracy:  34.5%
# Epoch  5, CIFAR-10 Batch 1:
#   Train Cost:   28.28050; Train Accuracy:  25.0%
#   Valid Cost:   26.61687; Valid Accuracy:  36.3%
# Epoch  5, CIFAR-10 Batch 2:
#   Train Cost:   20.28398; Train Accuracy:  40.0%
#   Valid Cost:   23.63147; Valid Accuracy:  35.6%
# Epoch  5, CIFAR-10 Batch 3:
#   Train Cost:   19.32086; Train Accuracy:  40.0%
#   Valid Cost:   21.97771; Valid Accuracy:  36.4%
# Epoch  5, CIFAR-10 Batch 4:
#   Train Cost:   15.23396; Train Accuracy:  25.0%
#   Valid Cost:   18.78802; Valid Accuracy:  37.1%
# Epoch  5, CIFAR-10 Batch 5:
#   Train Cost:   10.33757; Train Accuracy:  35.0%
#   Valid Cost:   17.53895; Valid Accuracy:  35.5%
# Epoch  6, CIFAR-10 Batch 1:
#   Train Cost:   17.04502; Train Accuracy:  35.0%
#   Valid Cost:   14.62582; Valid Accuracy:  37.0%
# Epoch  6, CIFAR-10 Batch 2:
#   Train Cost:   11.37983; Train Accuracy:  32.5%
#   Valid Cost:   14.26374; Valid Accuracy:  36.6%
# Epoch  6, CIFAR-10 Batch 3:
#   Train Cost:   12.20111; Train Accuracy:  32.5%
#   Valid Cost:   12.69001; Valid Accuracy:  36.2%
# Epoch  6, CIFAR-10 Batch 4:
#   Train Cost:    8.77891; Train Accuracy:  45.0%
#   Valid Cost:   10.96867; Valid Accuracy:  36.8%
# Epoch  6, CIFAR-10 Batch 5:
#   Train Cost:    5.28198; Train Accuracy:  50.0%
#   Valid Cost:    9.48933; Valid Accuracy:  36.9%
# Epoch  7, CIFAR-10 Batch 1:
#   Train Cost:   10.57984; Train Accuracy:  27.5%
#   Valid Cost:    8.68274; Valid Accuracy:  36.5%
# Epoch  7, CIFAR-10 Batch 2:
#   Train Cost:    6.18522; Train Accuracy:  40.0%
#   Valid Cost:    7.62981; Valid Accuracy:  36.8%
# Epoch  7, CIFAR-10 Batch 3:
#   Train Cost:    5.69871; Train Accuracy:  42.5%
#   Valid Cost:    7.20526; Valid Accuracy:  35.0%
# Epoch  7, CIFAR-10 Batch 4:
#   Train Cost:    5.53613; Train Accuracy:  40.0%
#   Valid Cost:    6.10756; Valid Accuracy:  36.3%
# Epoch  7, CIFAR-10 Batch 5:
#   Train Cost:    3.46174; Train Accuracy:  42.5%
#   Valid Cost:    5.29128; Valid Accuracy:  36.2%
# Epoch  8, CIFAR-10 Batch 1:
#   Train Cost:    7.55663; Train Accuracy:  22.5%
#   Valid Cost:    5.17953; Valid Accuracy:  35.4%
# Epoch  8, CIFAR-10 Batch 2:
#   Train Cost:    3.13695; Train Accuracy:  30.0%
#   Valid Cost:    4.10079; Valid Accuracy:  35.1%
# Epoch  8, CIFAR-10 Batch 3:
#   Train Cost:    2.75000; Train Accuracy:  37.5%
#   Valid Cost:    3.76368; Valid Accuracy:  36.7%
# Epoch  8, CIFAR-10 Batch 4:
#   Train Cost:    4.21747; Train Accuracy:  30.0%
#   Valid Cost:    3.45624; Valid Accuracy:  34.7%
# Epoch  8, CIFAR-10 Batch 5:
#   Train Cost:    2.08614; Train Accuracy:  42.5%
#   Valid Cost:    3.13276; Valid Accuracy:  34.8%
# Epoch  9, CIFAR-10 Batch 1:
#   Train Cost:    3.83814; Train Accuracy:  27.5%
#   Valid Cost:    3.16504; Valid Accuracy:  33.9%
# Epoch  9, CIFAR-10 Batch 2:
#   Train Cost:    1.93425; Train Accuracy:  35.0%
#   Valid Cost:    2.50778; Valid Accuracy:  35.1%
# Epoch  9, CIFAR-10 Batch 3:
#   Train Cost:    1.95605; Train Accuracy:  25.0%
#   Valid Cost:    2.32979; Valid Accuracy:  34.3%
# Epoch  9, CIFAR-10 Batch 4:
#   Train Cost:    2.57361; Train Accuracy:  37.5%
#   Valid Cost:    2.26995; Valid Accuracy:  34.9%
# Epoch  9, CIFAR-10 Batch 5:
#   Train Cost:    1.77782; Train Accuracy:  30.0%
#   Valid Cost:    2.05682; Valid Accuracy:  34.9%
# Epoch 10, CIFAR-10 Batch 1:
#   Train Cost:    2.43694; Train Accuracy:  37.5%
#   Valid Cost:    1.95214; Valid Accuracy:  36.1%
# Epoch 10, CIFAR-10 Batch 2:
#   Train Cost:    1.69494; Train Accuracy:  37.5%
#   Valid Cost:    1.94745; Valid Accuracy:  36.0%
# Epoch 10, CIFAR-10 Batch 3:
#   Train Cost:    1.68090; Train Accuracy:  32.5%
#   Valid Cost:    1.86797; Valid Accuracy:  35.2%
# Epoch 10, CIFAR-10 Batch 4:
#   Train Cost:    1.85677; Train Accuracy:  32.5%
#   Valid Cost:    1.84855; Valid Accuracy:  36.3%
# Epoch 10, CIFAR-10 Batch 5:
#   Train Cost:    1.76065; Train Accuracy:  35.0%
#   Valid Cost:    1.87335; Valid Accuracy:  35.3%
# Epoch 11, CIFAR-10 Batch 1:
#   Train Cost:    2.14658; Train Accuracy:  30.0%
#   Valid Cost:    1.80309; Valid Accuracy:  36.3%
# Epoch 11, CIFAR-10 Batch 2:
#   Train Cost:    1.65655; Train Accuracy:  40.0%
#   Valid Cost:    1.78940; Valid Accuracy:  37.3%
# Epoch 11, CIFAR-10 Batch 3:
#   Train Cost:    1.58058; Train Accuracy:  45.0%
#   Valid Cost:    1.78738; Valid Accuracy:  34.9%
# Epoch 11, CIFAR-10 Batch 4:
#   Train Cost:    1.71722; Train Accuracy:  30.0%
#   Valid Cost:    1.75523; Valid Accuracy:  37.2%
# Epoch 11, CIFAR-10 Batch 5:
#   Train Cost:    1.67753; Train Accuracy:  40.0%
#   Valid Cost:    1.80615; Valid Accuracy:  35.8%
# Epoch 12, CIFAR-10 Batch 1:
#   Train Cost:    2.12034; Train Accuracy:  32.5%
#   Valid Cost:    1.73402; Valid Accuracy:  37.7%
# Epoch 12, CIFAR-10 Batch 2:
#   Train Cost:    1.60640; Train Accuracy:  45.0%
#   Valid Cost:    1.74492; Valid Accuracy:  37.7%
# Epoch 12, CIFAR-10 Batch 3:
#   Train Cost:    1.62581; Train Accuracy:  40.0%
#   Valid Cost:    1.76269; Valid Accuracy:  36.5%
# Epoch 12, CIFAR-10 Batch 4:
#   Train Cost:    1.84786; Train Accuracy:  37.5%
#   Valid Cost:    1.72096; Valid Accuracy:  38.1%
# Epoch 12, CIFAR-10 Batch 5:
#   Train Cost:    1.65439; Train Accuracy:  45.0%
#   Valid Cost:    1.76553; Valid Accuracy:  36.5%
# Epoch 13, CIFAR-10 Batch 1:
#   Train Cost:    2.06894; Train Accuracy:  40.0%
#   Valid Cost:    1.71654; Valid Accuracy:  39.1%
# Epoch 13, CIFAR-10 Batch 2:
#   Train Cost:    1.62019; Train Accuracy:  50.0%
#   Valid Cost:    1.72577; Valid Accuracy:  36.3%
# Epoch 13, CIFAR-10 Batch 3:
#   Train Cost:    1.54938; Train Accuracy:  40.0%
#   Valid Cost:    1.69574; Valid Accuracy:  38.2%
# Epoch 13, CIFAR-10 Batch 4:
#   Train Cost:    1.72983; Train Accuracy:  50.0%
#   Valid Cost:    1.69517; Valid Accuracy:  39.5%
# Epoch 13, CIFAR-10 Batch 5:
#   Train Cost:    1.66732; Train Accuracy:  42.5%
#   Valid Cost:    1.72072; Valid Accuracy:  38.2%
# Epoch 14, CIFAR-10 Batch 1:
#   Train Cost:    1.98586; Train Accuracy:  32.5%
#   Valid Cost:    1.67977; Valid Accuracy:  39.4%
# Epoch 14, CIFAR-10 Batch 2:
#   Train Cost:    1.49132; Train Accuracy:  47.5%
#   Valid Cost:    1.71516; Valid Accuracy:  37.0%
# Epoch 14, CIFAR-10 Batch 3:
#   Train Cost:    1.56508; Train Accuracy:  42.5%
#   Valid Cost:    1.68533; Valid Accuracy:  39.3%
# Epoch 14, CIFAR-10 Batch 4:
#   Train Cost:    1.57583; Train Accuracy:  47.5%
#   Valid Cost:    1.64341; Valid Accuracy:  41.4%
# Epoch 14, CIFAR-10 Batch 5:
#   Train Cost:    1.60775; Train Accuracy:  42.5%
#   Valid Cost:    1.66437; Valid Accuracy:  41.1%
# Epoch 15, CIFAR-10 Batch 1:
#   Train Cost:    1.96787; Train Accuracy:  45.0%
#   Valid Cost:    1.66486; Valid Accuracy:  40.7%
# Epoch 15, CIFAR-10 Batch 2:
#   Train Cost:    1.48541; Train Accuracy:  55.0%
#   Valid Cost:    1.65536; Valid Accuracy:  39.7%
# Epoch 15, CIFAR-10 Batch 3:
#   Train Cost:    1.53540; Train Accuracy:  37.5%
#   Valid Cost:    1.65423; Valid Accuracy:  40.4%
# Epoch 15, CIFAR-10 Batch 4:
#   Train Cost:    1.52472; Train Accuracy:  42.5%
#   Valid Cost:    1.66461; Valid Accuracy:  41.1%
# Epoch 15, CIFAR-10 Batch 5:
#   Train Cost:    1.62540; Train Accuracy:  35.0%
#   Valid Cost:    1.63950; Valid Accuracy:  43.0%
# Epoch 16, CIFAR-10 Batch 1:
#   Train Cost:    1.87263; Train Accuracy:  37.5%
#   Valid Cost:    1.62846; Valid Accuracy:  41.5%
# Epoch 16, CIFAR-10 Batch 2:
#   Train Cost:    1.46585; Train Accuracy:  55.0%
#   Valid Cost:    1.64918; Valid Accuracy:  39.2%
# Epoch 16, CIFAR-10 Batch 3:
#   Train Cost:    1.47038; Train Accuracy:  40.0%
#   Valid Cost:    1.65927; Valid Accuracy:  41.5%
# Epoch 16, CIFAR-10 Batch 4:
#   Train Cost:    1.57683; Train Accuracy:  40.0%
#   Valid Cost:    1.64522; Valid Accuracy:  41.6%
# Epoch 16, CIFAR-10 Batch 5:
#   Train Cost:    1.59345; Train Accuracy:  47.5%
#   Valid Cost:    1.63034; Valid Accuracy:  41.8%
# Epoch 17, CIFAR-10 Batch 1:
#   Train Cost:    1.76965; Train Accuracy:  40.0%
#   Valid Cost:    1.70567; Valid Accuracy:  40.2%
# Epoch 17, CIFAR-10 Batch 2:
#   Train Cost:    1.42018; Train Accuracy:  55.0%
#   Valid Cost:    1.62217; Valid Accuracy:  40.0%
# Epoch 17, CIFAR-10 Batch 3:
#   Train Cost:    1.45295; Train Accuracy:  47.5%
#   Valid Cost:    1.61665; Valid Accuracy:  40.4%
# Epoch 17, CIFAR-10 Batch 4:
#   Train Cost:    1.54703; Train Accuracy:  40.0%
#   Valid Cost:    1.66715; Valid Accuracy:  41.9%
# Epoch 17, CIFAR-10 Batch 5:
#   Train Cost:    1.61455; Train Accuracy:  40.0%
#   Valid Cost:    1.64973; Valid Accuracy:  42.0%
# Epoch 18, CIFAR-10 Batch 1:
#   Train Cost:    1.69915; Train Accuracy:  45.0%
#   Valid Cost:    1.61919; Valid Accuracy:  40.8%
# Epoch 18, CIFAR-10 Batch 2:
#   Train Cost:    1.43633; Train Accuracy:  50.0%
#   Valid Cost:    1.61500; Valid Accuracy:  41.4%
# Epoch 18, CIFAR-10 Batch 3:
#   Train Cost:    1.48985; Train Accuracy:  45.0%
#   Valid Cost:    1.58386; Valid Accuracy:  42.6%
# Epoch 18, CIFAR-10 Batch 4:
#   Train Cost:    1.53097; Train Accuracy:  45.0%
#   Valid Cost:    1.62040; Valid Accuracy:  41.8%
# Epoch 18, CIFAR-10 Batch 5:
#   Train Cost:    1.55496; Train Accuracy:  37.5%
#   Valid Cost:    1.58119; Valid Accuracy:  43.8%
# Epoch 19, CIFAR-10 Batch 1:
#   Train Cost:    1.67367; Train Accuracy:  50.0%
#   Valid Cost:    1.56019; Valid Accuracy:  43.8%
# Epoch 19, CIFAR-10 Batch 2:
#   Train Cost:    1.43588; Train Accuracy:  50.0%
#   Valid Cost:    1.63068; Valid Accuracy:  40.8%
# Epoch 19, CIFAR-10 Batch 3:
#   Train Cost:    1.45189; Train Accuracy:  47.5%
#   Valid Cost:    1.60475; Valid Accuracy:  41.6%
# Epoch 19, CIFAR-10 Batch 4:
#   Train Cost:    1.52323; Train Accuracy:  42.5%
#   Valid Cost:    1.58735; Valid Accuracy:  43.0%
# Epoch 19, CIFAR-10 Batch 5:
#   Train Cost:    1.58043; Train Accuracy:  40.0%
#   Valid Cost:    1.55690; Valid Accuracy:  45.3%
# Epoch 20, CIFAR-10 Batch 1:
#   Train Cost:    1.81726; Train Accuracy:  37.5%
#   Valid Cost:    1.65664; Valid Accuracy:  41.1%
# Epoch 20, CIFAR-10 Batch 2:
#   Train Cost:    1.44136; Train Accuracy:  50.0%
#   Valid Cost:    1.58643; Valid Accuracy:  42.0%
# Epoch 20, CIFAR-10 Batch 3:
#   Train Cost:    1.42929; Train Accuracy:  47.5%
#   Valid Cost:    1.59561; Valid Accuracy:  42.3%
# Epoch 20, CIFAR-10 Batch 4:
#   Train Cost:    1.49915; Train Accuracy:  47.5%
#   Valid Cost:    1.62473; Valid Accuracy:  45.0%
# Epoch 20, CIFAR-10 Batch 5:
#   Train Cost:    1.54762; Train Accuracy:  42.5%
#   Valid Cost:    1.54429; Valid Accuracy:  45.3%
# Epoch 21, CIFAR-10 Batch 1:
#   Train Cost:    1.70620; Train Accuracy:  50.0%
#   Valid Cost:    1.57879; Valid Accuracy:  44.1%
# Epoch 21, CIFAR-10 Batch 2:
#   Train Cost:    1.46742; Train Accuracy:  45.0%
#   Valid Cost:    1.58174; Valid Accuracy:  42.2%
# Epoch 21, CIFAR-10 Batch 3:
#   Train Cost:    1.35701; Train Accuracy:  55.0%
#   Valid Cost:    1.53376; Valid Accuracy:  44.4%
# Epoch 21, CIFAR-10 Batch 4:
#   Train Cost:    1.44771; Train Accuracy:  42.5%
#   Valid Cost:    1.53231; Valid Accuracy:  46.1%
# Epoch 21, CIFAR-10 Batch 5:
#   Train Cost:    1.48890; Train Accuracy:  50.0%
#   Valid Cost:    1.53497; Valid Accuracy:  45.9%
# Epoch 22, CIFAR-10 Batch 1:
#   Train Cost:    1.79338; Train Accuracy:  37.5%
#   Valid Cost:    1.64206; Valid Accuracy:  43.0%
# Epoch 22, CIFAR-10 Batch 2:
#   Train Cost:    1.41174; Train Accuracy:  50.0%
#   Valid Cost:    1.51506; Valid Accuracy:  45.5%
# Epoch 22, CIFAR-10 Batch 3:
#   Train Cost:    1.33813; Train Accuracy:  50.0%
#   Valid Cost:    1.51804; Valid Accuracy:  45.3%
# Epoch 22, CIFAR-10 Batch 4:
#   Train Cost:    1.47198; Train Accuracy:  47.5%
#   Valid Cost:    1.53400; Valid Accuracy:  46.1%
# Epoch 22, CIFAR-10 Batch 5:
#   Train Cost:    1.52070; Train Accuracy:  40.0%
#   Valid Cost:    1.53994; Valid Accuracy:  46.7%
# Epoch 23, CIFAR-10 Batch 1:
#   Train Cost:    1.66138; Train Accuracy:  47.5%
#   Valid Cost:    1.50701; Valid Accuracy:  46.8%
# Epoch 23, CIFAR-10 Batch 2:
#   Train Cost:    1.30656; Train Accuracy:  50.0%
#   Valid Cost:    1.53500; Valid Accuracy:  44.1%
# Epoch 23, CIFAR-10 Batch 3:
#   Train Cost:    1.33749; Train Accuracy:  55.0%
#   Valid Cost:    1.49942; Valid Accuracy:  46.3%
# Epoch 23, CIFAR-10 Batch 4:
#   Train Cost:    1.45808; Train Accuracy:  45.0%
#   Valid Cost:    1.50697; Valid Accuracy:  46.9%
# Epoch 23, CIFAR-10 Batch 5:
#   Train Cost:    1.53825; Train Accuracy:  40.0%
#   Valid Cost:    1.51628; Valid Accuracy:  47.8%
# Epoch 24, CIFAR-10 Batch 1:
#   Train Cost:    1.59944; Train Accuracy:  52.5%
#   Valid Cost:    1.48347; Valid Accuracy:  47.9%
# Epoch 24, CIFAR-10 Batch 2:
#   Train Cost:    1.26554; Train Accuracy:  55.0%
#   Valid Cost:    1.53375; Valid Accuracy:  45.9%
# Epoch 24, CIFAR-10 Batch 3:
#   Train Cost:    1.38487; Train Accuracy:  50.0%
#   Valid Cost:    1.50809; Valid Accuracy:  47.3%
# Epoch 24, CIFAR-10 Batch 4:
#   Train Cost:    1.46370; Train Accuracy:  40.0%
#   Valid Cost:    1.46587; Valid Accuracy:  47.6%
# Epoch 24, CIFAR-10 Batch 5:
#   Train Cost:    1.45427; Train Accuracy:  42.5%
#   Valid Cost:    1.48725; Valid Accuracy:  48.7%
# Epoch 25, CIFAR-10 Batch 1:
#   Train Cost:    1.55818; Train Accuracy:  52.5%
#   Valid Cost:    1.46916; Valid Accuracy:  47.8%
# Epoch 25, CIFAR-10 Batch 2:
#   Train Cost:    1.27026; Train Accuracy:  57.5%
#   Valid Cost:    1.47695; Valid Accuracy:  47.1%
# Epoch 25, CIFAR-10 Batch 3:
#   Train Cost:    1.29675; Train Accuracy:  50.0%
#   Valid Cost:    1.49291; Valid Accuracy:  46.5%
# Epoch 25, CIFAR-10 Batch 4:
#   Train Cost:    1.51067; Train Accuracy:  37.5%
#   Valid Cost:    1.50656; Valid Accuracy:  46.8%
# Epoch 25, CIFAR-10 Batch 5:
#   Train Cost:    1.43102; Train Accuracy:  45.0%
#   Valid Cost:    1.46087; Valid Accuracy:  49.6%
# Epoch 26, CIFAR-10 Batch 1:
#   Train Cost:    1.56682; Train Accuracy:  47.5%
#   Valid Cost:    1.47094; Valid Accuracy:  47.8%
# Epoch 26, CIFAR-10 Batch 2:
#   Train Cost:    1.27286; Train Accuracy:  55.0%
#   Valid Cost:    1.48319; Valid Accuracy:  46.1%
# Epoch 26, CIFAR-10 Batch 3:
#   Train Cost:    1.29443; Train Accuracy:  52.5%
#   Valid Cost:    1.47869; Valid Accuracy:  47.0%
# Epoch 26, CIFAR-10 Batch 4:
#   Train Cost:    1.38185; Train Accuracy:  42.5%
#   Valid Cost:    1.47083; Valid Accuracy:  47.5%
# Epoch 26, CIFAR-10 Batch 5:
#   Train Cost:    1.44193; Train Accuracy:  42.5%
#   Valid Cost:    1.48177; Valid Accuracy:  49.7%
# Epoch 27, CIFAR-10 Batch 1:
#   Train Cost:    1.46023; Train Accuracy:  50.0%
#   Valid Cost:    1.43604; Valid Accuracy:  49.3%
# Epoch 27, CIFAR-10 Batch 2:
#   Train Cost:    1.23651; Train Accuracy:  57.5%
#   Valid Cost:    1.44798; Valid Accuracy:  48.4%
# Epoch 27, CIFAR-10 Batch 3:
#   Train Cost:    1.30765; Train Accuracy:  45.0%
#   Valid Cost:    1.45124; Valid Accuracy:  48.2%
# Epoch 27, CIFAR-10 Batch 4:
#   Train Cost:    1.44319; Train Accuracy:  40.0%
#   Valid Cost:    1.43968; Valid Accuracy:  48.6%
# Epoch 27, CIFAR-10 Batch 5:
#   Train Cost:    1.63024; Train Accuracy:  45.0%
#   Valid Cost:    1.49832; Valid Accuracy:  50.2%
# Epoch 28, CIFAR-10 Batch 1:
#   Train Cost:    1.51255; Train Accuracy:  45.0%
#   Valid Cost:    1.41771; Valid Accuracy:  49.5%
# Epoch 28, CIFAR-10 Batch 2:
#   Train Cost:    1.19907; Train Accuracy:  55.0%
#   Valid Cost:    1.44327; Valid Accuracy:  49.1%
# Epoch 28, CIFAR-10 Batch 3:
#   Train Cost:    1.27241; Train Accuracy:  52.5%
#   Valid Cost:    1.44071; Valid Accuracy:  48.3%
# Epoch 28, CIFAR-10 Batch 4:
#   Train Cost:    1.42532; Train Accuracy:  37.5%
#   Valid Cost:    1.45497; Valid Accuracy:  48.5%
# Epoch 28, CIFAR-10 Batch 5:
#   Train Cost:    1.36194; Train Accuracy:  50.0%
#   Valid Cost:    1.41815; Valid Accuracy:  51.4%
# Epoch 29, CIFAR-10 Batch 1:
#   Train Cost:    1.47119; Train Accuracy:  50.0%
#   Valid Cost:    1.44426; Valid Accuracy:  48.6%
# Epoch 29, CIFAR-10 Batch 2:
#   Train Cost:    1.09369; Train Accuracy:  67.5%
#   Valid Cost:    1.42802; Valid Accuracy:  50.1%
# Epoch 29, CIFAR-10 Batch 3:
#   Train Cost:    1.21897; Train Accuracy:  47.5%
#   Valid Cost:    1.44623; Valid Accuracy:  48.6%
# Epoch 29, CIFAR-10 Batch 4:
#   Train Cost:    1.28736; Train Accuracy:  47.5%
#   Valid Cost:    1.40493; Valid Accuracy:  51.0%
# Epoch 29, CIFAR-10 Batch 5:
#   Train Cost:    1.39334; Train Accuracy:  55.0%
#   Valid Cost:    1.40642; Valid Accuracy:  51.0%
# Epoch 30, CIFAR-10 Batch 1:
#   Train Cost:    1.46296; Train Accuracy:  50.0%
#   Valid Cost:    1.38921; Valid Accuracy:  50.9%
# Epoch 30, CIFAR-10 Batch 2:
#   Train Cost:    1.12665; Train Accuracy:  62.5%
#   Valid Cost:    1.39534; Valid Accuracy:  51.0%
# Epoch 30, CIFAR-10 Batch 3:
#   Train Cost:    1.19939; Train Accuracy:  50.0%
#   Valid Cost:    1.41355; Valid Accuracy:  48.9%
# Epoch 30, CIFAR-10 Batch 4:
#   Train Cost:    1.29050; Train Accuracy:  50.0%
#   Valid Cost:    1.40816; Valid Accuracy:  50.6%
# Epoch 30, CIFAR-10 Batch 5:
#   Train Cost:    1.40797; Train Accuracy:  55.0%
#   Valid Cost:    1.39484; Valid Accuracy:  51.9%
# Epoch 31, CIFAR-10 Batch 1:
#   Train Cost:    1.46431; Train Accuracy:  40.0%
#   Valid Cost:    1.38637; Valid Accuracy:  51.4%
# Epoch 31, CIFAR-10 Batch 2:
#   Train Cost:    1.04367; Train Accuracy:  62.5%
#   Valid Cost:    1.43463; Valid Accuracy:  49.5%
# Epoch 31, CIFAR-10 Batch 3:
#   Train Cost:    1.19712; Train Accuracy:  55.0%
#   Valid Cost:    1.42446; Valid Accuracy:  49.6%
# Epoch 31, CIFAR-10 Batch 4:
#   Train Cost:    1.27273; Train Accuracy:  50.0%
#   Valid Cost:    1.38072; Valid Accuracy:  50.9%
# Epoch 31, CIFAR-10 Batch 5:
#   Train Cost:    1.41260; Train Accuracy:  55.0%
#   Valid Cost:    1.38412; Valid Accuracy:  52.2%
# Epoch 32, CIFAR-10 Batch 1:
#   Train Cost:    1.45649; Train Accuracy:  45.0%
#   Valid Cost:    1.42045; Valid Accuracy:  51.5%
# Epoch 32, CIFAR-10 Batch 2:
#   Train Cost:    1.12461; Train Accuracy:  60.0%
#   Valid Cost:    1.38930; Valid Accuracy:  51.0%
# Epoch 32, CIFAR-10 Batch 3:
#   Train Cost:    1.17243; Train Accuracy:  60.0%
#   Valid Cost:    1.39048; Valid Accuracy:  51.1%
# Epoch 32, CIFAR-10 Batch 4:
#   Train Cost:    1.20501; Train Accuracy:  60.0%
#   Valid Cost:    1.36754; Valid Accuracy:  52.0%
# Epoch 32, CIFAR-10 Batch 5:
#   Train Cost:    1.36139; Train Accuracy:  47.5%
#   Valid Cost:    1.40402; Valid Accuracy:  51.9%
# Epoch 33, CIFAR-10 Batch 1:
#   Train Cost:    1.39694; Train Accuracy:  50.0%
#   Valid Cost:    1.38666; Valid Accuracy:  52.1%
# Epoch 33, CIFAR-10 Batch 2:
#   Train Cost:    1.01420; Train Accuracy:  60.0%
#   Valid Cost:    1.45805; Valid Accuracy:  49.2%
# Epoch 33, CIFAR-10 Batch 3:
#   Train Cost:    1.24589; Train Accuracy:  50.0%
#   Valid Cost:    1.40740; Valid Accuracy:  49.9%
# Epoch 33, CIFAR-10 Batch 4:
#   Train Cost:    1.20637; Train Accuracy:  60.0%
#   Valid Cost:    1.36189; Valid Accuracy:  52.1%
# Epoch 33, CIFAR-10 Batch 5:
#   Train Cost:    1.41524; Train Accuracy:  60.0%
#   Valid Cost:    1.40826; Valid Accuracy:  52.2%
# Epoch 34, CIFAR-10 Batch 1:
#   Train Cost:    1.46193; Train Accuracy:  47.5%
#   Valid Cost:    1.39072; Valid Accuracy:  51.0%
# Epoch 34, CIFAR-10 Batch 2:
#   Train Cost:    1.09939; Train Accuracy:  60.0%
#   Valid Cost:    1.39546; Valid Accuracy:  51.6%
# Epoch 34, CIFAR-10 Batch 3:
#   Train Cost:    1.13358; Train Accuracy:  57.5%
#   Valid Cost:    1.37902; Valid Accuracy:  50.7%
# Epoch 34, CIFAR-10 Batch 4:
#   Train Cost:    1.16267; Train Accuracy:  60.0%
#   Valid Cost:    1.35433; Valid Accuracy:  52.9%
# Epoch 34, CIFAR-10 Batch 5:
#   Train Cost:    1.27826; Train Accuracy:  60.0%
#   Valid Cost:    1.39228; Valid Accuracy:  53.1%
# Epoch 35, CIFAR-10 Batch 1:
#   Train Cost:    1.46266; Train Accuracy:  47.5%
#   Valid Cost:    1.35136; Valid Accuracy:  52.7%
# Epoch 35, CIFAR-10 Batch 2:
#   Train Cost:    1.05965; Train Accuracy:  62.5%
#   Valid Cost:    1.35173; Valid Accuracy:  52.8%
# Epoch 35, CIFAR-10 Batch 3:
#   Train Cost:    1.07878; Train Accuracy:  55.0%
#   Valid Cost:    1.35928; Valid Accuracy:  51.5%
# Epoch 35, CIFAR-10 Batch 4:
#   Train Cost:    1.19404; Train Accuracy:  52.5%
#   Valid Cost:    1.34353; Valid Accuracy:  53.5%
# Epoch 35, CIFAR-10 Batch 5:
#   Train Cost:    1.26697; Train Accuracy:  60.0%
#   Valid Cost:    1.36039; Valid Accuracy:  53.5%
# Epoch 36, CIFAR-10 Batch 1:
#   Train Cost:    1.45202; Train Accuracy:  50.0%
#   Valid Cost:    1.36253; Valid Accuracy:  53.2%
# Epoch 36, CIFAR-10 Batch 2:
#   Train Cost:    1.08252; Train Accuracy:  65.0%
#   Valid Cost:    1.33805; Valid Accuracy:  52.9%
# Epoch 36, CIFAR-10 Batch 3:
#   Train Cost:    1.09163; Train Accuracy:  60.0%
#   Valid Cost:    1.36815; Valid Accuracy:  51.5%
# Epoch 36, CIFAR-10 Batch 4:
#   Train Cost:    1.16598; Train Accuracy:  55.0%
#   Valid Cost:    1.34474; Valid Accuracy:  52.9%
# Epoch 36, CIFAR-10 Batch 5:
#   Train Cost:    1.24634; Train Accuracy:  60.0%
#   Valid Cost:    1.37272; Valid Accuracy:  53.7%
# Epoch 37, CIFAR-10 Batch 1:
#   Train Cost:    1.35836; Train Accuracy:  47.5%
#   Valid Cost:    1.33613; Valid Accuracy:  53.7%
# Epoch 37, CIFAR-10 Batch 2:
#   Train Cost:    1.06287; Train Accuracy:  65.0%
#   Valid Cost:    1.35294; Valid Accuracy:  53.2%
# Epoch 37, CIFAR-10 Batch 3:
#   Train Cost:    1.06998; Train Accuracy:  52.5%
#   Valid Cost:    1.34687; Valid Accuracy:  52.1%
# Epoch 37, CIFAR-10 Batch 4:
#   Train Cost:    1.19542; Train Accuracy:  52.5%
#   Valid Cost:    1.32993; Valid Accuracy:  53.3%
# Epoch 37, CIFAR-10 Batch 5:
#   Train Cost:    1.27847; Train Accuracy:  57.5%
#   Valid Cost:    1.36116; Valid Accuracy:  52.7%
# Epoch 38, CIFAR-10 Batch 1:
#   Train Cost:    1.40082; Train Accuracy:  50.0%
#   Valid Cost:    1.35789; Valid Accuracy:  53.8%
# Epoch 38, CIFAR-10 Batch 2:
#   Train Cost:    1.03620; Train Accuracy:  65.0%
#   Valid Cost:    1.31023; Valid Accuracy:  54.4%
# Epoch 38, CIFAR-10 Batch 3:
#   Train Cost:    1.05217; Train Accuracy:  57.5%
#   Valid Cost:    1.34143; Valid Accuracy:  53.3%
# Epoch 38, CIFAR-10 Batch 4:
#   Train Cost:    1.15076; Train Accuracy:  60.0%
#   Valid Cost:    1.31330; Valid Accuracy:  54.3%
# Epoch 38, CIFAR-10 Batch 5:
#   Train Cost:    1.28585; Train Accuracy:  62.5%
#   Valid Cost:    1.34507; Valid Accuracy:  54.3%
# Epoch 39, CIFAR-10 Batch 1:
#   Train Cost:    1.34761; Train Accuracy:  47.5%
#   Valid Cost:    1.34104; Valid Accuracy:  53.9%
# Epoch 39, CIFAR-10 Batch 2:
#   Train Cost:    1.01685; Train Accuracy:  60.0%
#   Valid Cost:    1.30825; Valid Accuracy:  54.6%
# Epoch 39, CIFAR-10 Batch 3:
#   Train Cost:    1.03755; Train Accuracy:  57.5%
#   Valid Cost:    1.30736; Valid Accuracy:  53.7%
# Epoch 39, CIFAR-10 Batch 4:
#   Train Cost:    1.14306; Train Accuracy:  55.0%
#   Valid Cost:    1.34035; Valid Accuracy:  54.4%
# Epoch 39, CIFAR-10 Batch 5:
#   Train Cost:    1.17778; Train Accuracy:  57.5%
#   Valid Cost:    1.33351; Valid Accuracy:  54.3%
# Epoch 40, CIFAR-10 Batch 1:
#   Train Cost:    1.31953; Train Accuracy:  50.0%
#   Valid Cost:    1.34981; Valid Accuracy:  54.5%
# Epoch 40, CIFAR-10 Batch 2:
#   Train Cost:    1.08688; Train Accuracy:  62.5%
#   Valid Cost:    1.30572; Valid Accuracy:  54.5%
# Epoch 40, CIFAR-10 Batch 3:
#   Train Cost:    1.05103; Train Accuracy:  60.0%
#   Valid Cost:    1.30181; Valid Accuracy:  54.1%
# Epoch 40, CIFAR-10 Batch 4:
#   Train Cost:    1.13730; Train Accuracy:  57.5%
#   Valid Cost:    1.31839; Valid Accuracy:  55.0%
# Epoch 40, CIFAR-10 Batch 5:
#   Train Cost:    1.18057; Train Accuracy:  60.0%
#   Valid Cost:    1.34458; Valid Accuracy:  54.6%
# Epoch 41, CIFAR-10 Batch 1:
#   Train Cost:    1.32751; Train Accuracy:  52.5%
#   Valid Cost:    1.34870; Valid Accuracy:  54.1%
# Epoch 41, CIFAR-10 Batch 2:
#   Train Cost:    1.06684; Train Accuracy:  70.0%
#   Valid Cost:    1.33081; Valid Accuracy:  52.9%
# Epoch 41, CIFAR-10 Batch 3:
#   Train Cost:    1.04206; Train Accuracy:  62.5%
#   Valid Cost:    1.30649; Valid Accuracy:  54.3%
# Epoch 41, CIFAR-10 Batch 4:
#   Train Cost:    1.17010; Train Accuracy:  60.0%
#   Valid Cost:    1.32186; Valid Accuracy:  54.7%
# Epoch 41, CIFAR-10 Batch 5:
#   Train Cost:    1.16095; Train Accuracy:  65.0%
#   Valid Cost:    1.35912; Valid Accuracy:  54.9%
# Epoch 42, CIFAR-10 Batch 1:
#   Train Cost:    1.26024; Train Accuracy:  50.0%
#   Valid Cost:    1.35354; Valid Accuracy:  54.7%
# Epoch 42, CIFAR-10 Batch 2:
#   Train Cost:    0.99667; Train Accuracy:  67.5%
#   Valid Cost:    1.30228; Valid Accuracy:  55.4%
# Epoch 42, CIFAR-10 Batch 3:
#   Train Cost:    1.01672; Train Accuracy:  57.5%
#   Valid Cost:    1.31414; Valid Accuracy:  54.4%
# Epoch 42, CIFAR-10 Batch 4:
#   Train Cost:    1.13558; Train Accuracy:  62.5%
#   Valid Cost:    1.32261; Valid Accuracy:  55.1%
# Epoch 42, CIFAR-10 Batch 5:
#   Train Cost:    1.11068; Train Accuracy:  67.5%
#   Valid Cost:    1.36226; Valid Accuracy:  55.1%
# Epoch 43, CIFAR-10 Batch 1:
#   Train Cost:    1.22805; Train Accuracy:  52.5%
#   Valid Cost:    1.34464; Valid Accuracy:  55.1%
# Epoch 43, CIFAR-10 Batch 2:
#   Train Cost:    0.97282; Train Accuracy:  65.0%
#   Valid Cost:    1.30531; Valid Accuracy:  55.4%
# Epoch 43, CIFAR-10 Batch 3:
#   Train Cost:    0.98899; Train Accuracy:  62.5%
#   Valid Cost:    1.33370; Valid Accuracy:  53.6%
# Epoch 43, CIFAR-10 Batch 4:
#   Train Cost:    1.11866; Train Accuracy:  62.5%
#   Valid Cost:    1.34711; Valid Accuracy:  55.0%
# Epoch 43, CIFAR-10 Batch 5:
#   Train Cost:    1.13116; Train Accuracy:  65.0%
#   Valid Cost:    1.32199; Valid Accuracy:  55.9%
# Epoch 44, CIFAR-10 Batch 1:
#   Train Cost:    1.22932; Train Accuracy:  60.0%
#   Valid Cost:    1.32836; Valid Accuracy:  55.8%
# Epoch 44, CIFAR-10 Batch 2:
#   Train Cost:    0.92049; Train Accuracy:  70.0%
#   Valid Cost:    1.29976; Valid Accuracy:  55.8%
# Epoch 44, CIFAR-10 Batch 3:
#   Train Cost:    0.98302; Train Accuracy:  60.0%
#   Valid Cost:    1.32866; Valid Accuracy:  53.9%
# Epoch 44, CIFAR-10 Batch 4:
#   Train Cost:    1.17669; Train Accuracy:  55.0%
#   Valid Cost:    1.35290; Valid Accuracy:  54.9%
# Epoch 44, CIFAR-10 Batch 5:
#   Train Cost:    1.08729; Train Accuracy:  67.5%
#   Valid Cost:    1.34243; Valid Accuracy:  55.5%
# Epoch 45, CIFAR-10 Batch 1:
#   Train Cost:    1.25044; Train Accuracy:  52.5%
#   Valid Cost:    1.31600; Valid Accuracy:  55.6%
# Epoch 45, CIFAR-10 Batch 2:
#   Train Cost:    0.95338; Train Accuracy:  67.5%
#   Valid Cost:    1.29972; Valid Accuracy:  56.0%
# Epoch 45, CIFAR-10 Batch 3:
#   Train Cost:    0.95287; Train Accuracy:  62.5%
#   Valid Cost:    1.30844; Valid Accuracy:  54.9%
# Epoch 45, CIFAR-10 Batch 4:
#   Train Cost:    1.16226; Train Accuracy:  62.5%
#   Valid Cost:    1.32426; Valid Accuracy:  55.0%
# Epoch 45, CIFAR-10 Batch 5:
#   Train Cost:    1.09675; Train Accuracy:  67.5%
#   Valid Cost:    1.32041; Valid Accuracy:  55.7%
# Epoch 46, CIFAR-10 Batch 1:
#   Train Cost:    1.18388; Train Accuracy:  55.0%
#   Valid Cost:    1.31415; Valid Accuracy:  55.5%
# Epoch 46, CIFAR-10 Batch 2:
#   Train Cost:    0.91993; Train Accuracy:  67.5%
#   Valid Cost:    1.30383; Valid Accuracy:  55.8%
# Epoch 46, CIFAR-10 Batch 3:
#   Train Cost:    0.97379; Train Accuracy:  60.0%
#   Valid Cost:    1.33280; Valid Accuracy:  53.9%
# Epoch 46, CIFAR-10 Batch 4:
#   Train Cost:    1.07874; Train Accuracy:  62.5%
#   Valid Cost:    1.33182; Valid Accuracy:  55.2%
# Epoch 46, CIFAR-10 Batch 5:
#   Train Cost:    1.01888; Train Accuracy:  65.0%
#   Valid Cost:    1.34712; Valid Accuracy:  55.8%
# Epoch 47, CIFAR-10 Batch 1:
#   Train Cost:    1.21501; Train Accuracy:  55.0%
#   Valid Cost:    1.34873; Valid Accuracy:  55.2%
# Epoch 47, CIFAR-10 Batch 2:
#   Train Cost:    0.88258; Train Accuracy:  67.5%
#   Valid Cost:    1.30005; Valid Accuracy:  56.2%
# Epoch 47, CIFAR-10 Batch 3:
#   Train Cost:    0.97854; Train Accuracy:  60.0%
#   Valid Cost:    1.30529; Valid Accuracy:  54.7%
# Epoch 47, CIFAR-10 Batch 4:
#   Train Cost:    1.05379; Train Accuracy:  62.5%
#   Valid Cost:    1.33274; Valid Accuracy:  55.3%
# Epoch 47, CIFAR-10 Batch 5:
#   Train Cost:    1.05445; Train Accuracy:  65.0%
#   Valid Cost:    1.35301; Valid Accuracy:  55.8%
# Epoch 48, CIFAR-10 Batch 1:
#   Train Cost:    1.18008; Train Accuracy:  52.5%
#   Valid Cost:    1.32582; Valid Accuracy:  56.0%
# Epoch 48, CIFAR-10 Batch 2:
#   Train Cost:    0.87052; Train Accuracy:  70.0%
#   Valid Cost:    1.31329; Valid Accuracy:  56.5%
# Epoch 48, CIFAR-10 Batch 3:
#   Train Cost:    0.95059; Train Accuracy:  60.0%
#   Valid Cost:    1.32353; Valid Accuracy:  55.2%
# Epoch 48, CIFAR-10 Batch 4:
#   Train Cost:    1.06642; Train Accuracy:  60.0%
#   Valid Cost:    1.31782; Valid Accuracy:  55.8%
# Epoch 48, CIFAR-10 Batch 5:
#   Train Cost:    0.99767; Train Accuracy:  65.0%
#   Valid Cost:    1.34677; Valid Accuracy:  55.3%
# Epoch 49, CIFAR-10 Batch 1:
#   Train Cost:    1.14917; Train Accuracy:  52.5%
#   Valid Cost:    1.34612; Valid Accuracy:  55.8%
# Epoch 49, CIFAR-10 Batch 2:
#   Train Cost:    0.86680; Train Accuracy:  70.0%
#   Valid Cost:    1.30960; Valid Accuracy:  55.7%
# Epoch 49, CIFAR-10 Batch 3:
#   Train Cost:    0.91209; Train Accuracy:  65.0%
#   Valid Cost:    1.35359; Valid Accuracy:  54.3%
# Epoch 49, CIFAR-10 Batch 4:
#   Train Cost:    1.08785; Train Accuracy:  60.0%
#   Valid Cost:    1.32618; Valid Accuracy:  55.5%
# Epoch 49, CIFAR-10 Batch 5:
#   Train Cost:    1.02211; Train Accuracy:  60.0%
#   Valid Cost:    1.34361; Valid Accuracy:  55.8%
# Epoch 50, CIFAR-10 Batch 1:
#   Train Cost:    1.10714; Train Accuracy:  52.5%
#   Valid Cost:    1.35529; Valid Accuracy:  55.6%
# Epoch 50, CIFAR-10 Batch 2:
#   Train Cost:    0.89980; Train Accuracy:  67.5%
#   Valid Cost:    1.29970; Valid Accuracy:  56.5%
# Epoch 50, CIFAR-10 Batch 3:
#   Train Cost:    0.92868; Train Accuracy:  60.0%
#   Valid Cost:    1.32405; Valid Accuracy:  55.7%
# Epoch 50, CIFAR-10 Batch 4:
#   Train Cost:    1.08890; Train Accuracy:  60.0%
#   Valid Cost:    1.33118; Valid Accuracy:  56.1%
# Epoch 50, CIFAR-10 Batch 5:
#   Train Cost:    1.02706; Train Accuracy:  62.5%
#   Valid Cost:    1.32324; Valid Accuracy:  56.0%
# Epoch 51, CIFAR-10 Batch 1:
#   Train Cost:    1.17172; Train Accuracy:  55.0%
#   Valid Cost:    1.34709; Valid Accuracy:  55.4%
# Epoch 51, CIFAR-10 Batch 2:
#   Train Cost:    0.90614; Train Accuracy:  62.5%
#   Valid Cost:    1.32524; Valid Accuracy:  55.9%
# Epoch 51, CIFAR-10 Batch 3:
#   Train Cost:    0.91579; Train Accuracy:  67.5%
#   Valid Cost:    1.32643; Valid Accuracy:  55.8%
# Epoch 51, CIFAR-10 Batch 4:
#   Train Cost:    1.03945; Train Accuracy:  67.5%
#   Valid Cost:    1.34201; Valid Accuracy:  55.7%
# Epoch 51, CIFAR-10 Batch 5:
#   Train Cost:    1.00744; Train Accuracy:  65.0%
#   Valid Cost:    1.31410; Valid Accuracy:  55.9%
# Epoch 52, CIFAR-10 Batch 1:
#   Train Cost:    1.15134; Train Accuracy:  52.5%
#   Valid Cost:    1.31494; Valid Accuracy:  56.4%
# Epoch 52, CIFAR-10 Batch 2:
#   Train Cost:    0.82159; Train Accuracy:  67.5%
#   Valid Cost:    1.31841; Valid Accuracy:  56.3%
# Epoch 52, CIFAR-10 Batch 3:
#   Train Cost:    0.99294; Train Accuracy:  62.5%
#   Valid Cost:    1.34237; Valid Accuracy:  55.7%
# Epoch 52, CIFAR-10 Batch 4:
#   Train Cost:    0.99948; Train Accuracy:  67.5%
#   Valid Cost:    1.33593; Valid Accuracy:  55.7%
# Epoch 52, CIFAR-10 Batch 5:
#   Train Cost:    0.94890; Train Accuracy:  67.5%
#   Valid Cost:    1.32717; Valid Accuracy:  56.3%
# Epoch 53, CIFAR-10 Batch 1:
#   Train Cost:    1.07518; Train Accuracy:  57.5%
#   Valid Cost:    1.32764; Valid Accuracy:  56.1%
# Epoch 53, CIFAR-10 Batch 2:
#   Train Cost:    0.84584; Train Accuracy:  70.0%
#   Valid Cost:    1.33252; Valid Accuracy:  56.5%
# Epoch 53, CIFAR-10 Batch 3:
#   Train Cost:    0.98537; Train Accuracy:  62.5%
#   Valid Cost:    1.34984; Valid Accuracy:  55.9%
# Epoch 53, CIFAR-10 Batch 4:
#   Train Cost:    1.02310; Train Accuracy:  65.0%
#   Valid Cost:    1.32987; Valid Accuracy:  56.1%
# Epoch 53, CIFAR-10 Batch 5:
#   Train Cost:    0.91356; Train Accuracy:  72.5%
#   Valid Cost:    1.32640; Valid Accuracy:  56.3%
# Epoch 54, CIFAR-10 Batch 1:
#   Train Cost:    1.08759; Train Accuracy:  60.0%
#   Valid Cost:    1.31899; Valid Accuracy:  55.9%
# Epoch 54, CIFAR-10 Batch 2:
#   Train Cost:    0.83074; Train Accuracy:  67.5%
#   Valid Cost:    1.30461; Valid Accuracy:  55.7%
# Epoch 54, CIFAR-10 Batch 3:
#   Train Cost:    0.92471; Train Accuracy:  62.5%
#   Valid Cost:    1.33710; Valid Accuracy:  56.3%
# Epoch 54, CIFAR-10 Batch 4:
#   Train Cost:    0.96077; Train Accuracy:  70.0%
#   Valid Cost:    1.35854; Valid Accuracy:  55.5%
# Epoch 54, CIFAR-10 Batch 5:
#   Train Cost:    0.93887; Train Accuracy:  72.5%
#   Valid Cost:    1.33081; Valid Accuracy:  56.5%
# Epoch 55, CIFAR-10 Batch 1:
#   Train Cost:    1.05750; Train Accuracy:  60.0%
#   Valid Cost:    1.34311; Valid Accuracy:  56.2%
# Epoch 55, CIFAR-10 Batch 2:
#   Train Cost:    0.79693; Train Accuracy:  65.0%
#   Valid Cost:    1.31834; Valid Accuracy:  56.4%
# Epoch 55, CIFAR-10 Batch 3:
#   Train Cost:    0.90486; Train Accuracy:  62.5%
#   Valid Cost:    1.34608; Valid Accuracy:  55.7%
# Epoch 55, CIFAR-10 Batch 4:
#   Train Cost:    0.94173; Train Accuracy:  67.5%
#   Valid Cost:    1.35394; Valid Accuracy:  55.6%
# Epoch 55, CIFAR-10 Batch 5:
#   Train Cost:    0.91013; Train Accuracy:  72.5%
#   Valid Cost:    1.33133; Valid Accuracy:  56.3%
# Epoch 56, CIFAR-10 Batch 1:
#   Train Cost:    1.03491; Train Accuracy:  62.5%
#   Valid Cost:    1.33602; Valid Accuracy:  56.6%
# Epoch 56, CIFAR-10 Batch 2:
#   Train Cost:    0.80903; Train Accuracy:  72.5%
#   Valid Cost:    1.33309; Valid Accuracy:  56.3%
# Epoch 56, CIFAR-10 Batch 3:
#   Train Cost:    0.92913; Train Accuracy:  62.5%
#   Valid Cost:    1.33163; Valid Accuracy:  55.6%
# Epoch 56, CIFAR-10 Batch 4:
#   Train Cost:    0.89993; Train Accuracy:  70.0%
#   Valid Cost:    1.34388; Valid Accuracy:  55.7%
# Epoch 56, CIFAR-10 Batch 5:
#   Train Cost:    0.92582; Train Accuracy:  65.0%
#   Valid Cost:    1.34860; Valid Accuracy:  55.6%
# Epoch 57, CIFAR-10 Batch 1:
#   Train Cost:    1.09329; Train Accuracy:  55.0%
#   Valid Cost:    1.33646; Valid Accuracy:  55.4%
# Epoch 57, CIFAR-10 Batch 2:
#   Train Cost:    0.79063; Train Accuracy:  72.5%
#   Valid Cost:    1.31295; Valid Accuracy:  56.7%
# Epoch 57, CIFAR-10 Batch 3:
#   Train Cost:    0.87712; Train Accuracy:  75.0%
#   Valid Cost:    1.33044; Valid Accuracy:  56.0%
# Epoch 57, CIFAR-10 Batch 4:
#   Train Cost:    0.86400; Train Accuracy:  70.0%
#   Valid Cost:    1.35034; Valid Accuracy:  55.4%
# Epoch 57, CIFAR-10 Batch 5:
#   Train Cost:    0.85620; Train Accuracy:  72.5%
#   Valid Cost:    1.34224; Valid Accuracy:  56.2%
# Epoch 58, CIFAR-10 Batch 1:
#   Train Cost:    1.04264; Train Accuracy:  57.5%
#   Valid Cost:    1.32003; Valid Accuracy:  56.0%
# Epoch 58, CIFAR-10 Batch 2:
#   Train Cost:    0.79062; Train Accuracy:  75.0%
#   Valid Cost:    1.31553; Valid Accuracy:  56.2%
# Epoch 58, CIFAR-10 Batch 3:
#   Train Cost:    0.89718; Train Accuracy:  67.5%
#   Valid Cost:    1.34742; Valid Accuracy:  56.0%
# Epoch 58, CIFAR-10 Batch 4:
#   Train Cost:    0.90484; Train Accuracy:  70.0%
#   Valid Cost:    1.35421; Valid Accuracy:  55.7%
# Epoch 58, CIFAR-10 Batch 5:
#   Train Cost:    0.81288; Train Accuracy:  75.0%
#   Valid Cost:    1.38083; Valid Accuracy:  55.5%
# Epoch 59, CIFAR-10 Batch 1:
#   Train Cost:    0.99881; Train Accuracy:  57.5%
#   Valid Cost:    1.35148; Valid Accuracy:  55.4%
# Epoch 59, CIFAR-10 Batch 2:
#   Train Cost:    0.73754; Train Accuracy:  75.0%
#   Valid Cost:    1.32342; Valid Accuracy:  56.3%
# Epoch 59, CIFAR-10 Batch 3:
#   Train Cost:    0.86651; Train Accuracy:  75.0%
#   Valid Cost:    1.31250; Valid Accuracy:  56.0%
# Epoch 59, CIFAR-10 Batch 4:
#   Train Cost:    0.91057; Train Accuracy:  72.5%
#   Valid Cost:    1.36601; Valid Accuracy:  55.3%
# Epoch 59, CIFAR-10 Batch 5:
#   Train Cost:    0.88368; Train Accuracy:  70.0%
#   Valid Cost:    1.37208; Valid Accuracy:  56.1%
# Epoch 60, CIFAR-10 Batch 1:
#   Train Cost:    1.03486; Train Accuracy:  60.0%
#   Valid Cost:    1.37424; Valid Accuracy:  55.9%
# Epoch 60, CIFAR-10 Batch 2:
#   Train Cost:    0.71168; Train Accuracy:  75.0%
#   Valid Cost:    1.35136; Valid Accuracy:  56.0%
# Epoch 60, CIFAR-10 Batch 3:
#   Train Cost:    0.85608; Train Accuracy:  72.5%
#   Valid Cost:    1.35178; Valid Accuracy:  55.5%
# Epoch 60, CIFAR-10 Batch 4:
#   Train Cost:    0.85745; Train Accuracy:  75.0%
#   Valid Cost:    1.36358; Valid Accuracy:  55.8%
# Epoch 60, CIFAR-10 Batch 5:
#   Train Cost:    0.80578; Train Accuracy:  77.5%
#   Valid Cost:    1.36016; Valid Accuracy:  56.2%
# Epoch 61, CIFAR-10 Batch 1:
#   Train Cost:    0.98519; Train Accuracy:  57.5%
#   Valid Cost:    1.36153; Valid Accuracy:  55.6%
# Epoch 61, CIFAR-10 Batch 2:
#   Train Cost:    0.71530; Train Accuracy:  77.5%
#   Valid Cost:    1.37806; Valid Accuracy:  55.5%
# Epoch 61, CIFAR-10 Batch 3:
#   Train Cost:    0.90610; Train Accuracy:  65.0%
#   Valid Cost:    1.36151; Valid Accuracy:  55.7%
# Epoch 61, CIFAR-10 Batch 4:
#   Train Cost:    0.88182; Train Accuracy:  72.5%
#   Valid Cost:    1.37474; Valid Accuracy:  56.0%
# Epoch 61, CIFAR-10 Batch 5:
#   Train Cost:    0.83354; Train Accuracy:  65.0%
#   Valid Cost:    1.37746; Valid Accuracy:  56.4%
# Epoch 62, CIFAR-10 Batch 1:
#   Train Cost:    1.02320; Train Accuracy:  57.5%
#   Valid Cost:    1.38338; Valid Accuracy:  55.3%
# Epoch 62, CIFAR-10 Batch 2:
#   Train Cost:    0.70197; Train Accuracy:  72.5%
#   Valid Cost:    1.36161; Valid Accuracy:  55.9%
# Epoch 62, CIFAR-10 Batch 3:
#   Train Cost:    0.84597; Train Accuracy:  70.0%
#   Valid Cost:    1.33557; Valid Accuracy:  56.1%
# Epoch 62, CIFAR-10 Batch 4:
#   Train Cost:    0.83217; Train Accuracy:  72.5%
#   Valid Cost:    1.37942; Valid Accuracy:  55.6%
# Epoch 62, CIFAR-10 Batch 5:
#   Train Cost:    0.81604; Train Accuracy:  75.0%
#   Valid Cost:    1.38314; Valid Accuracy:  56.0%
# Epoch 63, CIFAR-10 Batch 1:
#   Train Cost:    0.96698; Train Accuracy:  60.0%
#   Valid Cost:    1.37788; Valid Accuracy:  55.4%
# Epoch 63, CIFAR-10 Batch 2:
#   Train Cost:    0.69481; Train Accuracy:  77.5%
#   Valid Cost:    1.37724; Valid Accuracy:  56.0%
# Epoch 63, CIFAR-10 Batch 3:
#   Train Cost:    0.83514; Train Accuracy:  75.0%
#   Valid Cost:    1.36607; Valid Accuracy:  55.8%
# Epoch 63, CIFAR-10 Batch 4:
#   Train Cost:    0.88165; Train Accuracy:  67.5%
#   Valid Cost:    1.40696; Valid Accuracy:  55.3%
# Epoch 63, CIFAR-10 Batch 5:
#   Train Cost:    0.78197; Train Accuracy:  77.5%
#   Valid Cost:    1.38523; Valid Accuracy:  56.3%
# Epoch 64, CIFAR-10 Batch 1:
#   Train Cost:    0.94970; Train Accuracy:  60.0%
#   Valid Cost:    1.42745; Valid Accuracy:  54.6%
# Epoch 64, CIFAR-10 Batch 2:
#   Train Cost:    0.70806; Train Accuracy:  75.0%
#   Valid Cost:    1.41602; Valid Accuracy:  55.6%
# Epoch 64, CIFAR-10 Batch 3:
#   Train Cost:    0.81040; Train Accuracy:  75.0%
#   Valid Cost:    1.35856; Valid Accuracy:  56.2%
# Epoch 64, CIFAR-10 Batch 4:
#   Train Cost:    0.93314; Train Accuracy:  70.0%
#   Valid Cost:    1.40508; Valid Accuracy:  55.7%
# Epoch 64, CIFAR-10 Batch 5:
#   Train Cost:    0.74990; Train Accuracy:  77.5%
#   Valid Cost:    1.40389; Valid Accuracy:  56.2%

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.5588176751592356

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
